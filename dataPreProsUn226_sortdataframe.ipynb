# %%
# Warming Up
import pandas as pd
import numpy as np
from random import randrange 
from sklearn.model_selection import train_test_split

fPath = './data/vgsales.csv'
df = pd.read_csv(fPath)

# trying to create 1.5% worth of duplicates
rws = df.shape[0]
col = df.shape[1]
rwRtio = int(.015 * rws) # float is truncated

print('Number of instances before duplication = %d' % (rws))

def eenyMeeny():
     # select a random row
    tg = df.iloc[randrange(0, rws)]
    # return randomly selected row
    return tg

for i in range(rwRtio):
    df = df.append(eenyMeeny(), ignore_index=True)
rws = df.shape[0]

print('Number of instances after duplication = %d' % (len(rws)))
print('Number of attributes = %d' % (col))
print(df.head())
# Out:
# Number of instances before duplication = 16598
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28128\2229803926.py in ?()
#      20     # return randomly selected row
#      21     return tg
#      22
#      23 for i in range(rwRtio):
# ---> 24     df = df.append(eenyMeeny(), ignore_index=True)
#      25 rws = df.shape[0]
#      26
#      27 print('Number of instances after duplication = %d' % (len(rws)))
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# ### Missing Values

# %%
data = df.replace('?',np.NaN)

print('Number of instances = %d' % (rws))
print('Number of attributes = %d' % (col))

print('Number of missing values:')
for col in df.columns:
    print('\t%s: %d' % (col,df[col].isna().sum()))
# Out:
# Number of instances = 16598
# Number of attributes = 11
# Number of missing values:
# 	Rank: 0
# 	Name: 0
# 	Platform: 0
# 	Year: 271
# 	Genre: 0
# 	Publisher: 58
# 	NA_Sales: 0
# 	EU_Sales: 0
# 	JP_Sales: 0
# 	Other_Sales: 0
# 	Global_Sales: 0

# %%
print('Number of rows in original data = %d' % (rws))
df = df.dropna()
print('Number of rows after discarding missing values = %d' % (df.shape[0]))
print('Difference in number of rows = %d' % (rws-df.shape[0]))
# update rws
rws = df.shape[0]
# Out:
# Number of rows in original data = 16598
# Number of rows after discarding missing values = 16291
# Difference in number of rows = 307

# %% [markdown]
# ### Outliers

# %%
pass

# %% [markdown]
# ### Duplicat Data

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %% [markdown]
# ## Sampling

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
sample = data.sample(n=10)
sample
# Out:
#         Rank                                               Name Platform  \
# 1324    1326                                 4 Nin uchi Mahjong      NES
# 15578  15581  Metal Fight Beyblade Portable: Chouzetsu Tense...      PSP
# 3953    3955                                     Midnight Magic     2600
# 11076  11078                       Action Man-Operation Extreme       PS
# 2700    2702                    Super Monkey Ball: Touch & Roll       DS
# 14905  14908             Gakuen Alice: WakuWaku * Happy Friends       DS
# 15825  15828                                   Puyo Puyo Tetris     WiiU
# 6439    6441       Gallop Racer 2: One and Only Road to Victory       PS
# 2622    2624                                   NCAA Football 08      PS2
# 13930  13932                               Train Simulator 2016       PC
#
#          Year       Genre        Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 1324   1984.0        Misc         Nintendo      0.00      0.00      1.45
# 15578  2010.0      Action      Takara Tomy      0.00      0.00      0.02
# 3953   1983.0      Action            Atari      0.47      0.03      0.00
# 11076     NaN      Action              NaN      0.05      0.03      0.00
# 2700   2005.0        Misc             Sega      0.70      0.01      0.00
# 14905  2007.0   Adventure     Kids Station      0.00      0.00      0.03
# 15825  2014.0      Puzzle             Sega      0.00      0.00      0.02
# 6439   1997.0      Sports       Tecmo Koei      0.00      0.00      0.25
# 2622   2007.0      Sports  Electronic Arts      0.65      0.03      0.00
# 13930  2015.0  Simulation          Unknown      0.00      0.04      0.00
#
#        Other_Sales  Global_Sales
# 1324          0.00          1.45
# 15578         0.00          0.02
# 3953          0.01          0.50
# 11076         0.01          0.09
# 2700          0.06          0.76
# 14905         0.00          0.03
# 15825         0.00          0.02
# 6439          0.02          0.27
# 2622          0.11          0.79
# 13930         0.00          0.04

# %%
sample = data.sample(frac=0.01, random_state=999)
sample
# Out:
#         Rank                                               Name Platform  \
# 10725  10727  The Land Before Time: Great Valley Racing Adve...       PS
# 9053    9055                                              Mojo!      PS2
# 10102  10104                                    Vacation Sports      Wii
# 11876  11878                       Disney's Donald Duck Advance      GBA
# 14561  14564  Gekiatsu!! Pachi Game Tamashi Vol. 1: CR Evang...      PSP
# ...      ...                                                ...      ...
# 6592    6594            Silent Hunter 5: Battle of the Atlantic       PC
# 4539    4541                        EverQuest Online Adventures      PS2
# 9920    9922                       SD Gundam G Generation-F.I.F       PS
# 14440  14443                  Eyeshield 21: DevilBats DevilDays      GBA
# 12075  12077          Space Hulk: Vengeance of the Blood Angels       PS
#
#          Year         Genre                  Publisher  NA_Sales  EU_Sales  \
# 10725  2001.0        Racing             TDK Mediactive      0.05      0.04
# 9053   2003.0        Puzzle                  Mindscape      0.07      0.05
# 10102  2009.0        Sports                    Ubisoft      0.10      0.01
# 11876  2001.0      Platform                    Ubisoft      0.05      0.02
# 14561  2011.0          Misc                    Unknown      0.00      0.00
# ...       ...           ...                        ...       ...       ...
# 6592   2010.0    Simulation                    Ubisoft      0.00      0.21
# 4539   2003.0  Role-Playing  Sony Online Entertainment      0.21      0.16
# 9920   2001.0      Strategy         Namco Bandai Games      0.00      0.00
# 14440  2006.0  Role-Playing                   Nintendo      0.00      0.00
# 12075  1995.0       Shooter            Electronic Arts      0.04      0.03
#
#        JP_Sales  Other_Sales  Global_Sales
# 10725      0.00         0.01          0.10
# 9053       0.00         0.02          0.14
# 10102      0.00         0.01          0.11
# 11876      0.00         0.00          0.07
# 14561      0.03         0.00          0.03
# ...         ...          ...           ...
# 6592       0.00         0.05          0.26
# 4539       0.00         0.05          0.43
# 9920       0.11         0.01          0.12
# 14440      0.03         0.00          0.03
# 12075      0.00         0.00          0.07
#
# [166 rows x 11 columns]

# %%
sample = data.sample(frac=0.01, replace=True, random_state=999)
sample
# Out:
#         Rank                                               Name Platform  \
# 12636  12638                                 Adventures of Lolo      NES
# 13157  13159                              Nike+ Kinect Training     X360
# 5832    5834                  Karaoke Revolution Glee: Volume 3      Wii
# 8417    8419                WRC 2: FIA World Rally Championship      PS3
# 10715  10717                                 Lord of Apocalypse      PSP
# ...      ...                                                ...      ...
# 5585    5587                       Resident Evil: Revelations 2      PS3
# 10519  10521                            God Eater 2: Rage Burst      PS4
# 6322    6324  Fushigi no Dungeon: Fuurai no Shiren GB: Tsuki...       GB
# 1982    1984                                   Forza Motorsport       XB
# 5130    5132    Command & Conquer: Red Alert 3 Ultimate Edition      PS3
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 12636  1989.0        Puzzle                HAL Laboratory      0.06      0.00
# 13157  2012.0        Sports        Microsoft Game Studios      0.02      0.02
# 5832   2011.0          Misc  Konami Digital Entertainment      0.24      0.04
# 8417   2011.0        Racing                       Ubisoft      0.00      0.13
# 10715  2011.0  Role-Playing                   Square Enix      0.00      0.00
# ...       ...           ...                           ...       ...       ...
# 5585   2015.0        Action                        Capcom      0.06      0.08
# 10519  2015.0  Role-Playing            Namco Bandai Games      0.00      0.01
# 6322   1996.0  Role-Playing                      ChunSoft      0.00      0.00
# 1982   2005.0        Racing        Microsoft Game Studios      0.52      0.51
# 5130   2009.0      Strategy               Electronic Arts      0.14      0.17
#
#        JP_Sales  Other_Sales  Global_Sales
# 12636      0.00         0.00          0.06
# 13157      0.00         0.00          0.05
# 5832       0.00         0.02          0.30
# 8417       0.00         0.04          0.17
# 10715      0.10         0.00          0.10
# ...         ...          ...           ...
# 5585       0.16         0.03          0.32
# 10519      0.09         0.00          0.10
# 6322       0.27         0.00          0.27
# 1982       0.00         0.02          1.05
# 5130       0.00         0.06          0.37
#
# [166 rows x 11 columns]

# %% [markdown]
# # Shuffle the dataframe and save it

# %%
df = df.reindex(np.random.permutation(df.index))
df
# Out:
#         Rank                                               Name Platform  \
# 11991  11993                                 Hearts of Iron III       PC
# 9267    9269     Avatar: The Last Airbender - The Burning Earth     X360
# 14399  14402                            Super Heroine Chronicle      PS3
# 16037  16040                WRC 5: FIA World Rally Championship     XOne
# 13143  13145                   The Lost Treasures of Alexandria       DS
# ...      ...                                                ...      ...
# 6031    6033                 Bladestorm: The Hundred Years' War      PS3
# 2093    2095                            Oddworld: Abe's Exoddus       PS
# 12037  12039                     Ultimate Board Game Collection      PSP
# 2035    2037                      The Lost World: Jurassic Park       PS
# 12859  12861  Shiren the Wanderer 5 Plus: Fortune Tower and ...      PSV
#
#          Year         Genre            Publisher  NA_Sales  EU_Sales  \
# 11991  2009.0      Strategy  Paradox Interactive      0.01      0.04
# 9267   2007.0        Action                  THQ      0.11      0.01
# 14399  2014.0  Role-Playing   Namco Bandai Games      0.00      0.00
# 16037  2015.0        Sports   Bigben Interactive      0.00      0.01
# 13143  2011.0        Puzzle              Unknown      0.00      0.04
# ...       ...           ...                  ...       ...       ...
# 6031   2007.0        Action           Tecmo Koei      0.10      0.03
# 2093   1998.0      Platform       GT Interactive      0.55      0.38
# 12037  2007.0          Misc              Xplosiv      0.06      0.00
# 2035   1997.0        Action      Electronic Arts      0.57      0.39
# 12859  2015.0        Action          Aksys Games      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 11991      0.00         0.01          0.07
# 9267       0.00         0.01          0.14
# 14399      0.03         0.00          0.03
# 16037      0.00         0.00          0.01
# 13143      0.00         0.01          0.05
# ...         ...          ...           ...
# 6031       0.14         0.02          0.29
# 2093       0.00         0.06          0.99
# 12037      0.00         0.01          0.07
# 2035       0.00         0.07          1.02
# 12859      0.04         0.00          0.05
#
# [16291 rows x 11 columns]

# %%
df.reset_index(inplace=True, drop=True)
df
# Out:
#         Rank                                               Name Platform  \
# 0      11993                                 Hearts of Iron III       PC
# 1       9269     Avatar: The Last Airbender - The Burning Earth     X360
# 2      14402                            Super Heroine Chronicle      PS3
# 3      16040                WRC 5: FIA World Rally Championship     XOne
# 4      13145                   The Lost Treasures of Alexandria       DS
# ...      ...                                                ...      ...
# 16286   6033                 Bladestorm: The Hundred Years' War      PS3
# 16287   2095                            Oddworld: Abe's Exoddus       PS
# 16288  12039                     Ultimate Board Game Collection      PSP
# 16289   2037                      The Lost World: Jurassic Park       PS
# 16290  12861  Shiren the Wanderer 5 Plus: Fortune Tower and ...      PSV
#
#          Year         Genre            Publisher  NA_Sales  EU_Sales  \
# 0      2009.0      Strategy  Paradox Interactive      0.01      0.04
# 1      2007.0        Action                  THQ      0.11      0.01
# 2      2014.0  Role-Playing   Namco Bandai Games      0.00      0.00
# 3      2015.0        Sports   Bigben Interactive      0.00      0.01
# 4      2011.0        Puzzle              Unknown      0.00      0.04
# ...       ...           ...                  ...       ...       ...
# 16286  2007.0        Action           Tecmo Koei      0.10      0.03
# 16287  1998.0      Platform       GT Interactive      0.55      0.38
# 16288  2007.0          Misc              Xplosiv      0.06      0.00
# 16289  1997.0        Action      Electronic Arts      0.57      0.39
# 16290  2015.0        Action          Aksys Games      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 0          0.00         0.01          0.07
# 1          0.00         0.01          0.14
# 2          0.03         0.00          0.03
# 3          0.00         0.00          0.01
# 4          0.00         0.01          0.05
# ...         ...          ...           ...
# 16286      0.14         0.02          0.29
# 16287      0.00         0.06          0.99
# 16288      0.00         0.01          0.07
# 16289      0.00         0.07          1.02
# 16290      0.04         0.00          0.05
#
# [16291 rows x 11 columns]

# %% [markdown]
# # Sort the dataframe

# %%
print("Before sorting")
print(df['Global_Sales'])
df = df.sort_values(by='Global_Sales',ascending=True)

print("\nAfter sorting")
print(df['Global_Sales'])
# Out:
# Before sorting
# 0        0.07
# 1        0.14
# 2        0.03
# 3        0.01
# 4        0.05
#          ...
# 16286    0.29
# 16287    0.99
# 16288    0.07
# 16289    1.02
# 16290    0.05
# Name: Global_Sales, Length: 16291, dtype: float64
#
# After sorting
# 3573      0.01
# 6268      0.01
# 6304      0.01
# 12769     0.01
# 6305      0.01
#          ...
# 3381     31.37
# 9278     33.00
# 7896     35.82
# 3063     40.24
# 4624     82.74
# Name: Global_Sales, Length: 16291, dtype: float64

# %%
print("df['Global_Sales'].iloc[0] is: {}".format(df['Global_Sales'].iloc[0]))

print("df['Global_Sales'].loc[0] is: {}".format(df['Global_Sales'].loc[0]))
# Out:
# df['Global_Sales'].iloc[0] is: 0.01
# df['Global_Sales'].loc[0] is: 0.07

# %%
#Sorting in Ascending Order
#Sorting by column 'NA_Sales'
df = df.sort_values(by=['NA_Sales'],ascending=True)
df
# Out:
#         Rank                                               Name Platform  \
# 15515   8432            Sumikko Gurashi: Koko ga Ochitsukundesu      3DS
# 9818   13807                Zac to Ombra: Maboroshi no Yuuenchi       DS
# 9827   13773  Dolly Kanon Dokidoki Tokimeki Himitsu no Ongak...      3DS
# 9841   13790         Who Wants to be a Millionaire: 1st Edition       DS
# 16162   4701                                 Mobile Suit Gundam      SAT
# ...      ...                                                ...      ...
# 7896       3                                     Mario Kart Wii      Wii
# 14358      6                                             Tetris       GB
# 12368     10                                          Duck Hunt      NES
# 3063       2                                  Super Mario Bros.      NES
# 4624       1                                         Wii Sports      Wii
#
#          Year      Genre                     Publisher  NA_Sales  EU_Sales  \
# 15515  2014.0     Action               Nippon Columbia      0.00      0.00
# 9818   2010.0  Adventure  Konami Digital Entertainment      0.00      0.00
# 9827   2014.0  Adventure                      Happinet      0.00      0.00
# 9841   2007.0       Misc                       Ubisoft      0.00      0.04
# 16162  1995.0     Action            Namco Bandai Games      0.00      0.00
# ...       ...        ...                           ...       ...       ...
# 7896   2008.0     Racing                      Nintendo     15.85     12.88
# 14358  1989.0     Puzzle                      Nintendo     23.20      2.26
# 12368  1984.0    Shooter                      Nintendo     26.93      0.63
# 3063   1985.0   Platform                      Nintendo     29.08      3.58
# 4624   2006.0     Sports                      Nintendo     41.49     29.02
#
#        JP_Sales  Other_Sales  Global_Sales
# 15515      0.17         0.00          0.17
# 9818       0.04         0.00          0.04
# 9827       0.04         0.00          0.04
# 9841       0.00         0.00          0.04
# 16162      0.41         0.00          0.41
# ...         ...          ...           ...
# 7896       3.79         3.31         35.82
# 14358      4.22         0.58         30.26
# 12368      0.28         0.47         28.31
# 3063       6.81         0.77         40.24
# 4624       3.77         8.46         82.74
#
# [16291 rows x 11 columns]

# %%
#Sorting in Descending Order
#Sorting by column "EU_Sales"
df = df.sort_values(by=['EU_Sales'], ascending=False)
df
# Out:
#         Rank                                     Name Platform    Year  \
# 4624       1                               Wii Sports      Wii  2006.0
# 7896       3                           Mario Kart Wii      Wii  2008.0
# 9278       4                        Wii Sports Resort      Wii  2009.0
# 1341      11                               Nintendogs       DS  2005.0
# 2909      17                       Grand Theft Auto V      PS3  2013.0
# ...      ...                                      ...      ...     ...
# 1669   15772  Clock Zero: Shuuen no Ichibyou - ExTime      PSV  2015.0
# 13115   6865           Jikkyou Powerful Pro Yakyuu 15      PS2  2008.0
# 12143  15113                          School Days LxH      PS2  2008.0
# 475    15757             L.G.S: Shinsetsu Houshinengi      PSP  2012.0
# 15515   8432  Sumikko Gurashi: Koko ga Ochitsukundesu      3DS  2014.0
#
#             Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 4624       Sports                      Nintendo     41.49     29.02      3.77
# 7896       Racing                      Nintendo     15.85     12.88      3.79
# 9278       Sports                      Nintendo     15.75     11.01      3.28
# 1341   Simulation                      Nintendo      9.07     11.00      1.93
# 2909       Action          Take-Two Interactive      7.01      9.27      0.97
# ...           ...                           ...       ...       ...       ...
# 1669       Action                  Idea Factory      0.00      0.00      0.02
# 13115      Sports  Konami Digital Entertainment      0.00      0.00      0.24
# 12143   Adventure                  Interchannel      0.00      0.00      0.02
# 475        Action                  Idea Factory      0.00      0.00      0.02
# 15515      Action               Nippon Columbia      0.00      0.00      0.17
#
#        Other_Sales  Global_Sales
# 4624          8.46         82.74
# 7896          3.31         35.82
# 9278          2.96         33.00
# 1341          2.75         24.76
# 2909          4.14         21.40
# ...            ...           ...
# 1669          0.00          0.02
# 13115         0.00          0.24
# 12143         0.00          0.02
# 475           0.00          0.02
# 15515         0.00          0.17
#
# [16291 rows x 11 columns]
